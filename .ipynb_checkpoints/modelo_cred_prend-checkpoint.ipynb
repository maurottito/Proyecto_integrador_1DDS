# %%
#importamos librerias
#pip install pyreadstat
import pyreadstat
import pandas as pd
from pyprojroot import here 
from janitor import clean_names
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Cargando la data
data, meta = pyreadstat.read_sav(here() / "Input/Credito prendario.sav")

# %%
data.head()
# Out:
#     Periodo        CodCli  Edad  Sexo  EstaCiv  TipoViv  CantCred    Desem  \
# 0  200705.0  1.090300e+12  69.0   1.0      1.0      1.0       2.0  2613.74
# 1  200705.0  1.090300e+12  55.0   0.0      5.0      4.0       2.0  2782.07
# 2  200705.0  1.090300e+12  55.0   0.0      1.0      4.0       1.0  1407.21
# 3  200705.0  1.090300e+12  61.0   0.0      1.0      4.0       2.0   658.70
# 4  200705.0  1.090300e+12  59.0   0.0      5.0      4.0       2.0  2162.62
#
#    SalVigSol  Monto_Tasación  DiasEfec  MaxDeuda  FlagAtra  MaxDiasAtra  \
# 0    2549.54         2736.90     551.0   2690.89       0.0          6.0
# 1    1488.64         3051.00    1327.0   1790.80       0.0         33.0
# 2    1205.06         1473.52    1645.0   4315.00       0.0         28.0
# 3     429.95         1095.28     424.0    399.62       1.0         28.0
# 4    2148.78         2264.52    1213.0   1642.20       0.0         46.0
#
#    MaxGramOro  FechAnalisis  AntiDias  FlagAdj
# 0     45.4166  1.341369e+10     220.0      0.0
# 1     50.6250  1.341619e+10     233.0      0.0
# 2     24.4500  1.342328e+10     327.0      0.0
# 3     12.4500  1.340729e+10     127.0      1.0
# 4     37.5750  1.342051e+10     275.0      0.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 961984 entries, 0 to 961983
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Periodo         961984 non-null  float64
#  1   CodCli          961984 non-null  float64
#  2   Edad            961984 non-null  float64
#  3   Sexo            961984 non-null  float64
#  4   EstaCiv         961984 non-null  float64
#  5   TipoViv         961984 non-null  float64
#  6   CantCred        961984 non-null  float64
#  7   Desem           961984 non-null  float64
#  8   SalVigSol       961984 non-null  float64
#  9   Monto_Tasación  961984 non-null  float64
#  10  DiasEfec        961984 non-null  float64
#  11  MaxDeuda        961984 non-null  float64
#  12  FlagAtra        961984 non-null  float64
#  13  MaxDiasAtra     961984 non-null  float64
#  14  MaxGramOro      961984 non-null  float64
#  15  FechAnalisis    961984 non-null  float64
#  16  AntiDias        961984 non-null  float64
#  17  FlagAdj         961984 non-null  float64
# dtypes: float64(18)
# memory usage: 132.1 MB

# %%
data.describe()
# Out:
#              Periodo        CodCli           Edad           Sexo  \
# count  961984.000000  9.619840e+05  961984.000000  961984.000000
# mean   201286.775498  1.090327e+12      49.321998       0.276369
# std       358.527164  4.947873e+08      14.006775       0.447202
# min    200705.000000  1.090100e+12       4.000000       0.000000
# 25%    201003.000000  1.090100e+12      38.000000       0.000000
# 50%    201302.000000  1.090101e+12      49.000000       0.000000
# 75%    201604.000000  1.090400e+12      59.000000       1.000000
# max    201912.000000  1.094200e+12     121.000000       1.000000
#
#              EstaCiv        TipoViv       CantCred          Desem  \
# count  961984.000000  961984.000000  961984.000000  961984.000000
# mean        3.638882       3.373357       1.458078    1321.890569
# std         1.870402       0.698861       1.089123    2253.256632
# min         1.000000       1.000000       1.000000       0.000000
# 25%         1.000000       3.000000       1.000000     402.520000
# 50%         5.000000       3.000000       1.000000     765.000000
# 75%         5.000000       4.000000       2.000000    1496.000000
# max         6.000000       4.000000      56.000000  455218.040000
#
#            SalVigSol  Monto_Tasación       DiasEfec       MaxDeuda  \
# count  961984.000000   961984.000000  961984.000000  961984.000000
# mean     1141.981002     1534.603675    1410.237456    1796.333652
# std      2106.711828     2538.672621    1080.444301    2266.425110
# min         0.000000       48.600000       1.000000      50.000000
# 25%       324.407500      475.200000     534.000000     620.000000
# 50%       630.000000      897.600000    1146.000000    1150.050000
# 75%      1275.980000     1740.000000    2061.000000    2101.100000
# max    455218.040000   535552.800000    4834.000000   60120.500000
#
#             FlagAtra    MaxDiasAtra     MaxGramOro  FechAnalisis  \
# count  961984.000000  961984.000000  961984.000000  9.619840e+05
# mean        0.183141      22.789648      12.078409  1.363018e+10
# std         0.386783      21.842127      19.072081  1.232786e+08
# min         0.000000       0.000000       0.450000  1.340004e+10
# 25%         0.000000       9.000000       3.862500  1.352307e+10
# 50%         0.000000      20.000000       7.200000  1.363116e+10
# 75%         0.000000      28.000000      13.725000  1.374762e+10
# max         1.000000    1050.000000    3347.205000  1.380033e+10
#
#             AntiDias        FlagAdj
# count  961984.000000  961984.000000
# mean      730.859930       0.122391
# std       953.436639       0.327737
# min         0.000000       0.000000
# 25%       200.000000       0.000000
# 50%       371.000000       0.000000
# 75%       757.000000       0.000000
# max      4991.000000       1.000000

# %%
#Trayendo los label de Estacivil, tipo vivienda

# %%
#Eliminar los casos con Edad menor a 18 años:

# %%
sns.set_style('whitegrid')
sns.countplot(x='EstaCiv',data=data,palette='RdBu_r')
# Out:
# <AxesSubplot:xlabel='EstaCiv', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x='TipoViv',data=data,palette='RdBu_r')
# Out:
# <AxesSubplot:xlabel='TipoViv', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x='Sexo',data=data,palette='RdBu_r')
# Out:
# <AxesSubplot:xlabel='Sexo', ylabel='count'>
